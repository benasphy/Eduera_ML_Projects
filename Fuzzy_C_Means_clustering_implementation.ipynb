# %% [markdown]
# <a href="https://colab.research.google.com/github/benasphy/Eduera_ML_Projects/blob/main/Fuzzy_C_Means_clustering_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install and Import Required Libraries**

# %%
! pip install scikit-fuzzy
# Out:
# Collecting scikit-fuzzy
#   Downloading scikit_fuzzy-0.5.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Downloading scikit_fuzzy-0.5.0-py2.py3-none-any.whl (920 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.5.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
from sklearn.datasets import make_blobs
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# **Generate Synthetic Data**

# %%
X, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)

# %% [markdown]
# **Scale the Data**

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# **Define the Number of Clusters**

# %%
n_clusters = 3

# %% [markdown]
# **Apply Fuzzy C-Means Clustering**

# %%
cntr, u, _, _, _, _,_ = fuzz.cluster.cmeans(
    X.T, n_clusters, m = 2, error=0.005, maxiter=1000, init=None
)

# %% [markdown]
# **Get Final Cluster Labels**

# %%
cluster_labels = np.argmax(u, axis=0)

# %% [markdown]
# **Visualize the Results**

# %%
for i in range(n_clusters):
  plt.scatter(X[cluster_labels == i, 0], X[cluster_labels == i, 1], label = f"Cluster{i}")

plt.scatter(cntr[:, 0], cntr[:,1], c = "red", marker = "X", s = 200, label = "Centroids")
plt.legend()
plt.title("Fuzzy C-Means Clustering")
plt.show()
